# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('../dataset - netflix1.csv')

ds = pd.DataFrame(data)

ds
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
ds.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
ds.shape
# Out:
# (8790, 10)

# %%
ds.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
ds1 = ds.dropna()

ds1
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
sum(ds.duplicated())
# Out:
# 0

# %%
ds.select_dtypes(include=['int', 'float'])
# Out:
#       release_year
# 0             2020
# 1             2021
# 2             2021
# 3             2021
# 4             1993
# ...            ...
# 8785          2016
# 8786          2016
# 8787          2012
# 8788          2016
# 8789          2016
#
# [8790 rows x 1 columns]

# %%
sns.histplot(data=ds, x=ds['release_year'], kde = True)
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>

# %%
mean = ds['release_year'].mean()
std = ds['release_year'].std()
lower = mean - 2 * std
upper = mean + 2 * std

# Remove outliers based on the defined range
ds1 = ds[(ds['release_year'] >= lower) & (ds['release_year'] <= upper)]

# %%
ds['release_year'].describe()
# Out:
# count    8790.000000
# mean     2014.183163
# std         8.825466
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
ds1['release_year'].describe()
# Out:
# count    8378.000000
# mean     2015.727978
# std         4.788608
# min      1997.000000
# 25%      2014.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
ds.shape
# Out:
# (8790, 10)

# %%
ds1.shape
# Out:
# (8378, 10)
