# %%
import pandas as pd
import requests as rq

# %%
api = "https://data.binance.com/api/v3/ticker/24hr" 

response = rq.get(api)

data = response.json()

ds = pd.DataFrame(data)

ds.to_csv("api.csv", index=False)

# %%
ds.head()
# Out:
#     symbol  priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC   0.00101000              1.651       0.06167936     0.06118000
# 1   LTCBTC   0.00003300              1.368       0.00242172     0.00241300
# 2   BNBBTC   0.00001200              0.150       0.00797485     0.00801800
# 3   NEOBTC  -0.00000140             -0.513       0.00027017     0.00027250
# 4  QTUMETH  -0.00002800             -2.062       0.00134386     0.00136600
#
#     lastPrice       lastQty    bidPrice        bidQty    askPrice  ...  \
# 0  0.06220000    1.17260000  0.06219000   72.75960000  0.06220000  ...
# 1  0.00244500    4.08300000  0.00244400   47.15400000  0.00244500  ...
# 2  0.00803100    0.26700000  0.00803100   13.71700000  0.00803200  ...
# 3  0.00027140  250.00000000  0.00027150   31.69000000  0.00027180  ...
# 4  0.00133000    3.90000000  0.00133400  216.10000000  0.00133700  ...
#
#     openPrice   highPrice    lowPrice          volume    quoteVolume  \
# ...

# %%
ds.shape
# Out:
# (2302, 21)
